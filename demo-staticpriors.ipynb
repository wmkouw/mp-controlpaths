# %% [markdown]
# # Message passing - control paths

# %%
import Pkg;
Pkg.activate("."); 
Pkg.instantiate();
# Out:
#   Activating project at `~/syndr/Wouter/Onderzoek/Projecten/tue/infer-controlpaths/mp-controlpaths`

# %%
using Revise
using RxInfer
using Optim
using Plots
default(label="")

includet("Robots.jl"); using. Robots
includet("util.jl")

# %%
# Time
Δt = 0.2
len_trial = 100
tsteps = range(0, step=Δt, length=len_trial)

# Dimensions
Dy = 2
Dx = 4
Du = 2

# State transition
A = [1. 0. Δt 0.;
     0. 1. 0. Δt;
     0. 0. 1. 0.;
     0. 0. 0. 1.]

# Control matrix
B = [0. 0.;
     0. 0.;
     Δt 0.;
     0. Δt]

# Process noise covariance matrix
σ = [1e-2; 1e-2]
Q = [Δt^3/3*σ[1]            0.0    Δt^2/2*σ[1]            0.0;
     0.0            Δt^3/3*σ[2]            0.0    Δt^2/2*σ[2];
     Δt^2/2*σ[1]            0.0         Δt*σ[1]           0.0;
     0.0            Δt^2/2*σ[2]            0.0        Δt*σ[2]]

# Measurement function     
C = [1. 0. 0. 0.;
     0. 1. 0. 0.]

# Measurement noise covariance matrix
ρ = [1e-3, 1e-3]
R = diagm(ρ)

# Control prior precision
η = 1e0

# State prior parameters
m_0 = [0.0, 0.0, 0., 0.]
S_0 = 1e6diagm(ones(4));

# Goal prior
x_star = [1.0, 1.0, 0.0, 0.0]
m_star = C*x_star
S_star = 1e-8*diagm(ones(Dy))
# Out:
# 2×2 Matrix{Float64}:
#  1.0e-8  0.0
#  0.0     1.0e-8

# %%
@model function static_control_priors(y_k, u_k, A,B,Q,C,R,T, m_kmin1, S_kmin1, m_star, S_star)
    
    # Transition function 
    x_k ~ MvNormalMeanCovariance(A*m_kmin1 + B*u_k, Q + A*S_kmin1*A')
    
    # Measurement function
    y_k ~ MvNormalMeanCovariance(C*x_k, R)

    x_tmin1 = x_k
    for t in 1:T

        # Control prior
        u_[t] ~ MvNormalMeanCovariance(zeros(Du), η*diagm(ones(Du)))
        
        # Transition function 
        x_[t] ~ MvNormalMeanCovariance(A*x_tmin1 + B*u_[t], Q)
        
        # Measurement function
        y_[t] ~ MvNormalMeanCovariance(C*x_[t], R)

        # Future observation prior
        y_[t] ~ MvNormalMeanCovariance(m_star, S_star)

        x_tmin1 = x_[t]

    end
end

# %%
len_horizon = 10

# Initial state
x_0 = [0.0, 0.0, 0., 0.]

# Initialize robot
control_lims = (-1., 1.)
bot = FieldBot(ρ,σ, Δt=Δt, control_lims=control_lims)

y_sim = zeros(Dy, len_trial)
x_sim = zeros(Dx, len_trial)
u_sim = zeros(Du, len_trial+1)

x_kmin1 = x_0
m_kmin1 = x_0
S_kmin1 = 1e4*diagm(ones(Dx))

res = []

for k in 1:len_trial

    # Evolve system
    y_sim[:,k], x_sim[:,k] = update(bot, x_kmin1, u_sim[:,k])
    x_kmin1 = x_sim[:,k]

    # Agent absorbs observation
    global res = infer(
        model = static_control_priors(A=A,B=B,C=C,Q=Q,R=R,T=len_horizon),
        data = (y_k = y_sim[:,k], 
                u_k = u_sim[:,k],
                m_kmin1 = m_kmin1,
                S_kmin1 = S_kmin1,
                m_star = m_star,
                S_star = S_star),
    )

    # Extract state posterior
    m_kmin1 = mean(res.posteriors[:x_k])
    S_kmin1 = cov(res.posteriors[:x_k])

    # Extract control posterior
    u_sim[:,k+1] = mean(res.posteriors[:u_][1])

end

# %%
plot(y_sim')

# %%
plot(u_sim')
